# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals = [1600,600,300,410,250]
exp_labels = ['Home Rent','Food','Phone Bill','Car','Others']

# %%
plt.pie(exp_vals,labels=exp_labels,radius=1.5,autopct='%0.1f%%',explode=[0,0,0.1,0,0],startangle=45)
plt.show()
